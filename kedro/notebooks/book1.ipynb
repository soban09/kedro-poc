# %%
# %pip install kedro-datasets[pandas]
# Out:
# ...
#   Obtaining dependency information for kedro-datasets[pandas] from https://files.pythonhosted.org/packages/da/57/29be152276926f976c2041a9fa2712935ab10351d135f552e00b8508ce4b/kedro_datasets-6.0.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for lazy_loader from https://files.pythonhosted.org/packages/83/60/d497a310bde3f01cb805196ac61b7ad6dc5dcf8dce66634dc34364b20b4f/lazy_loader-0.4-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for deltalake>=0.10.0 from https://files.pythonhosted.org/packages/a1/74/be1d4d465b22526ecd2d2dc6b6cfa257285ac091a90ac86b99fcd043a7a5/deltalake-0.24.0-cp39-abi3-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for openpyxl<4.0,>=3.0.6 from https://files.pythonhosted.org/packages/c0/da/977ded879c29cbd04de313843e76868e6e13408a94ed6b987245dc7c8506/openpyxl-3.1.5-py2.py3-none-any.whl.metadata
# ...

# %%
# %load_ext kedro.ipython
# Out:
# The kedro.ipython extension is already loaded. To reload it, use:
#   %reload_ext kedro.ipython

# %%
# %reload_ext kedro.ipython
# Out:
# [02/07/25 16:12:21] INFO     Registered line magic '%reload_kedro'                                   ]8;id=4262;file://c:\Users\SobanFarooq\Documents\poc\mlops\Kedro\venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=439393;file://c:\Users\SobanFarooq\Documents\poc\mlops\Kedro\venv\Lib\site-packages\kedro\ipython\__init__.py#63\63]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=326996;file://c:\Users\SobanFarooq\Documents\poc\mlops\Kedro\venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=930753;file://c:\Users\SobanFarooq\Documents\poc\mlops\Kedro\venv\Lib\site-packages\kedro\ipython\__init__.py#65\65]8;;\
# ...

# %%
context
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# KedroContext(
#     project_path=WindowsPath('C:/Users/SobanFarooq/Documents/poc/mlops/Kedro/get-started'),
#     config_loader=OmegaConfigLoader(conf_source=C:\Users\SobanFarooq\Documents\poc\mlops\Kedro\get-started\conf, env=None, runtime_params={}, config_patterns={'catalog': ['catalog*', 'catalog*/**', '**/catalog*'], 'parameters': ['parameters*', 'parameters*/**', '**/parameters*'], 'credentials': ['credentials*', 'credentials*/**', '**/credentials*'], 'globals': ['globals.yml']}, base_env=base), default_run_env=local), custom_resolvers=None), merge_strategy={}),
#     env=None,
#     _package_name=None,
#     _hook_manager=<pluggy._manager.PluginManager object at 0x0000028E9FB55590>,
#     _extra_params=None
# )

# %%
session
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ...

# %%
catalog
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {'diabetes': "kedro_datasets.pandas.csv_dataset.CSVDataset(filepath=PurePosixPath('C:/Users/SobanFarooq/Documents/poc/mlops/Kedro/get-started/data/01_raw/diabetes-dev.csv'), "
#              "protocol='file', load_args={}, save_args={'index': False})",
#  'parameters': "kedro.io.memory_dataset.MemoryDataset(data='<dict>')"}

# %%
diabetes = catalog.load('diabetes-dev')
diabetes.head()
# Out:
# [02/07/25 16:12:52] INFO     Loading data from diabetes-dev (CSVDataset)...                     ]8;id=974241;file://c:\Users\SobanFarooq\Documents\poc\mlops\Kedro\venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=986674;file://c:\Users\SobanFarooq\Documents\poc\mlops\Kedro\venv\Lib\site-packages\kedro\io\data_catalog.py#390\390]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    PatientID  Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# 0    1142956            1             78                      41
# 1    1823377            0            116                      92
# 2    1916381            8            171                      42
# 3    1247480            3            108                      63
# 4    1516947            8            153                      99
#
#    TricepsThickness  SerumInsulin        BMI  DiabetesPedigree  Age  Diabetic
# ...

# %%
parameters
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 parameters                                                                                   │
# │   2                                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# NameError: name 'parameters' is not defined
